# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel('Prectice1.xlsx',index_col=[0,1,2])
df
# Out:
#                  RollNo   S1  S2  S3
# Collage Dep Sem
# ABC     CE  5       101  100  68  78
#             5       102   78  78  90
#         ME  5       103   89  89  89
#         CE  7       104   88  78  89
# Darshan CE  5       105   85  78  89
#         ME  5       106   89  89  89
#         CE  7       107   89  43  78

# %%
data = df.xs("CE",axis=0,level="Dep")

# %%
data
# Out:
#              RollNo   S1  S2  S3
# Collage Sem
# ABC     5       101  100  68  78
#         5       102   78  78  90
#         7       104   88  78  89
# Darshan 5       105   85  78  89
#         7       107   89  43  78

# %%
data = df.xs("CE",axis=0,level="Dep",drop_level=False)
data
# Out:
#                  RollNo   S1  S2  S3
# Collage Dep Sem
# ABC     CE  5       101  100  68  78
#             5       102   78  78  90
#             7       104   88  78  89
# Darshan CE  5       105   85  78  89
#             7       107   89  43  78
